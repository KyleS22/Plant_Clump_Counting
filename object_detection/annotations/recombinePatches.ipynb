# %%
import os
import cv2
import glob
import csv

import numpy as np

from math import ceil

# %%
IMGFOLDER  = "D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch\\"
PREDFOLDER = "D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\" # Predictions on patches

IMAGEEXT = ".png" # include the '.'
PREDEXT  = ".csv" # include the '.' # I don't think this can be anything other than .csv really...
PREDFNAMESUFFIX = "_boxes" # Between the image name and the extension

#DELIMITER = '_'

CROSS_PATCH_SUPPRESSION = 10 # This is the max number of pixels that if two boxes occur across the patch separator they will be combined

CROP_PADDING = 2 # Border-pad by this many pixels on each detction crop export

DILATE_KERNEL = np.ones((5,2),np.uint8)

# %%
patchfolders = [f.path for f in os.scandir(PREDFOLDER) if f.is_dir()]

print(patchfolders)
# Out:
# ['D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_369787469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_369788469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_369789469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_370787469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_370788469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_370789469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_371787469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_371788469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\03_371789469', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375793474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375793475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375793476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375794474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375794475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375794476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375795475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_375795476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376793474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376793475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376794474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376794475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376794476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376795474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376795475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_376795476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_377794474', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_377794475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_377794476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_377795475', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\05_377795476', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378797478', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378798477', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378798478', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378798479', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378799478', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_378799479', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_379797477', 'D:\\tensorflow\\projects\\PlantClumpDetection\\annotations\\output_stitch_outputs\\UNet\\06_379797478', 'D:\\tens ...

# %%
def returnBoxDict(xmin, ymin, xmax, ymax):
    '''
    Construct a box dictionary from xmin, ymin, xmax, and ymax, with (0,0) being the top-left corner
    
    :param int xmin: the location of the min x value of the box
    :param int ymin: the location of the min y value of the box
    :param int xmax: the location of the max x value of the box
    :param int ymax: the location of the max y value of the box
    :return: a dictionary defining a box containing (uint) values for the keys {x,y}{min,max}
    :rtype: dict
    '''
    tempDict = {}
    tempDict["xmin"] = xmin
    tempDict["ymin"] = ymin
    tempDict["xmax"] = xmax
    tempDict["ymax"] = ymax
    return tempDict

# %%
def decodeBoxFromDict(box):
    '''
    Get xmin, ymin, xmax, and ymax from a box dictionary
    
    :param dict box: a dictionary defining a box containing (uint) values for the keys {x,y}{min,max}
    :return: a tuple containing (uint) xmin, ymin, xmax, ymax from the appropriate keys in box
    :rtype: tup -> int, int, int, int
    '''
    xmin = box["xmin"]
    ymin = box["ymin"]
    xmax = box["xmax"]
    ymax = box["ymax"]
    return xmin, ymin, xmax, ymax

# %%
def combineBoxesAtBoundaries(boxes, boundaries, pxthresh, sort_key="xmin", no_y_check=False):
    '''
    Combines boxes within a list of boxes if they are within pxthresh on either side of a boundary in boundaries
    
    :param list boxes: a list of box dictionaries
    :param list boundaries: a list of integer boundaries
    :param int pxthresh: an integer threshold
    :return: a list of boxes where any box combinations at boundaries have occurred 
    :rtype: list
    '''
    pxthresh += 1 # In case of pesky off by one errors with < and >
    
    xminSorted = sorted(boxes, key=lambda x: x["xmin"])
    xmaxSorted = sorted(boxes, key=lambda x: x["xmax"])
    #print(xminSorted) # DEBUG
    #print(xmaxSorted) # DEBUG
    
    toCombine     = {}
    toCombineFlat = []
    xminIdx       = 0
    xmaxIdx       = 0
    
    for boundary in boundaries:
        while xmaxIdx < len(xmaxSorted):
            xmaxCurr    = xmaxSorted[xmaxIdx]
            xmaxCurrVal = xmaxCurr["xmax"]
            xmaxIdx += 1
            if xmaxCurrVal > boundary:
                break
            elif boundary-xmaxCurrVal < pxthresh:
                while xminIdx < len(xminSorted):
                    xminCurr    = xminSorted[xminIdx]
                    xminCurrVal = xminCurr["xmin"]
                    xminIdx += 1
                    if xminCurr is xmaxCurr:
                        continue
                    elif 0 <= xminCurrVal-boundary < pxthresh:
                        try:
                            if xmaxCurr not in toCombine[str(boundary)]:
                                toCombine[str(boundary)].append(xmaxCurr)
                                toCombineFlat.append(xmaxCurr)
                            if xminCurr not in toCombine[str(boundary)]:
                                toCombine[str(boundary)].append(xminCurr)
                                toCombineFlat.append(xminCurr)
                                print("COMBINING@boundary={} (again)".format(boundary))
                        except KeyError:
                            print("COMBINING@boundary={}".format(boundary))
                            toCombine[str(boundary)] = [xmaxCurr, xminCurr]
                            toCombineFlat.append(xmaxCurr)
                            toCombineFlat.append(xminCurr)
                    elif xminCurrVal <= boundary:
                        continue
                    else:
                        break
            else:
                continue
    
    toReturn   = []
    
    for box in boxes:
        if box not in toCombineFlat:
            toReturn.append(box)
    
    for boundary, comboList in toCombine.items():
        yminList = [box["ymin"] for box in comboList]
        ymaxList = [box["ymax"] for box in comboList]
        if (no_y_check) or (abs(np.mean(yminList)-min(yminList)) < pxthresh) or (abs(np.mean(ymaxList)-min(ymaxList)) < pxthresh):
            toReturn.append(returnBoxDict(min([box["xmin"] for box in comboList]), 
                                          min(yminList),
                                          max([box["xmax"] for box in comboList]),
                                          max(ymaxList)
                                         ))
        else:
            toReturn.extend(combo)
    
    toReturn.sort(key=lambda x: x[sort_key])
    return toReturn

# TESTS #
boxesTest = []
boxesTest.append(returnBoxDict(1,  5, 12, 10))
boxesTest.append(returnBoxDict(18, 4, 21, 11))
boxesTest.append(returnBoxDict(29, 7, 40, 12))
boxesTest.append(returnBoxDict(48, 5, 60, 10))
boxesTest.append(returnBoxDict(70, 6, 85, 10))
boxesTest.append(returnBoxDict(85, 4, 90, 9))
boxesTest.append(returnBoxDict(94, 4, 99, 9))
boxesTest.append(returnBoxDict(101, 3, 110, 12))
boxesTest.append(returnBoxDict(103, 1, 111, 9))

boxesOut = combineBoxesAtBoundaries(boxesTest, [25, 85, 100], 4)
for box in boxesOut:
    print(box)
# Out:
# COMBINING@boundary=25
# COMBINING@boundary=85
# COMBINING@boundary=100
# COMBINING@boundary=100 (again)
# {'xmin': 1, 'ymin': 5, 'xmax': 12, 'ymax': 10}
# {'xmin': 18, 'ymin': 4, 'xmax': 40, 'ymax': 12}
# {'xmin': 48, 'ymin': 5, 'xmax': 60, 'ymax': 10}
# {'xmin': 70, 'ymin': 4, 'xmax': 90, 'ymax': 10}
# {'xmin': 94, 'ymin': 1, 'xmax': 111, 'ymax': 12}

# %%
'''toRemove = []
toReturn = []

for boxA in boxes:
    comboList = []
    for boxB in boxes:
        if boxA is not boxB:
            if (boxA["xmin"] > boxB["xmax"] or boxB["xmin"] > boxA["xmax"] or boxA["ymin"] > boxB["ymax"] or boxB["ymin"] > boxA["ymax"]):
                pass
            else:
                comboList.append(boxB)
    if not comboList'''
# Out:
# 'toRemove = []\ntoReturn = []\n\nfor boxA in boxes:\n    comboList = []\n    for boxB in boxes:\n        if boxA is not boxB:\n            if (boxA["xmin"] > boxB["xmax"] or boxB["xmin"] > boxA["xmax"] or boxA["ymin"] > boxB["ymax"] or boxB["ymin"] > boxA["ymax"]):\n                pass\n            else:\n                comboList.append(boxB)\n    if not comboList'

# %%
for patchfolder in patchfolders:
    
    patchfoldername     = os.path.splitext(os.path.basename(patchfolder))[0]
    pathimagename       = patchfoldername + IMAGEEXT
    boxesCSVfilename    = patchfoldername + PREDFNAMESUFFIX + PREDEXT
    boxesCSVfilenameOut = patchfoldername + "_crops" + PREDEXT
    print("***** PROCESSING {} ... *****".format(pathimagename)) # DEBUG
    
    # Boxes
    boxes = []
    
    with open(os.path.join(patchfolder, boxesCSVfilename), newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='|')
        skipFirst = False
        for row in reader:
            if not skipFirst: # To remove the first line contianing only the headers 
                skipFirst = True
                continue
            boxes.append(returnBoxDict(int(row[0]), int(row[1]), int(row[2]), int(row[3])))
    
    #print(boxes) # DEBUG
    
    frame = cv2.imread(os.path.join(IMGFOLDER, pathimagename))
    if frame is None:
        print("WARNING: {} cannot be read. Skipping...".format(pathimagename))
        continue
    
    h, w, c = frame.shape
    numPatches    = int(ceil(w/h)) # Ceil 'cause we don't want to discard last information
    boundaryArr   = list(range(h,numPatches*h,h))
    #print(boundaryArr) # DEBUG
    
    new = frame.copy()
    blank = np.zeros((h, w, 3)).astype('uint8')
    #print(blank.shape) # DEBUG
    
    boxesOut = combineBoxesAtBoundaries(boxes, boundaryArr, CROSS_PATCH_SUPPRESSION, no_y_check=True)
    #print(boxesOut) # DEBUG
    
    padding = 0#CROSS_PATCH_SUPPRESSION//2
    for box in boxesOut:
        xmin, ymin, xmax, ymax = decodeBoxFromDict(box)
        cv2.rectangle(blank, (xmin-padding, ymin-padding), (xmax+padding, ymax+padding), (255, 255, 255), thickness=cv2.FILLED)
    
    mask = cv2.dilate(blank, DILATE_KERNEL, iterations=1)
    
    maskImageName = patchfoldername+"_mask"+IMAGEEXT
    cv2.imwrite(os.path.join(patchfolder, maskImageName), mask) # Export detection mask
    
    boxesOut2 = []
    gray_mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    im2, contours, hierarchy = cv2.findContours(gray_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        boxesOut2.append(returnBoxDict(x, y, x+w, y+h))
    
    boxesOut2 = sorted(boxesOut2, key=lambda x: x["xmin"])
    
    # Draw detection rectangles and save crops
    with open(os.path.join(patchfolder, boxesCSVfilenameOut), 'w', newline='') as csvfile:
        label = 1
        csvwriter = csv.writer(csvfile, delimiter=',',
                               quotechar='|', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow(['label', 'xmin', 'ymin', 'xmax', 'ymax'])
        
        for box in boxesOut2:
            xmin, ymin, xmax, ymax = decodeBoxFromDict(box)
            cv2.rectangle(new, (xmin, ymin), (xmax, ymax), (0, 255, 0), thickness=2)
            cropImageName = patchfoldername+"_"+'%03d'%label+IMAGEEXT
            cv2.imwrite(os.path.join(patchfolder, cropImageName), frame[ymin-CROP_PADDING:ymax+CROP_PADDING,xmin-CROP_PADDING:xmax+CROP_PADDING,:])
            csvwriter.writerow(['%03d'%label, xmin, ymin, xmax, ymax])
            label += 1
    
    cv2.imwrite(os.path.join(patchfolder, pathimagename), new) # Export detection image
    
    #break # DEBUG
# Out:
# ***** PROCESSING 03_369787469.png ... *****
# ***** PROCESSING 03_369788469.png ... *****
# ***** PROCESSING 03_369789469.png ... *****
# ***** PROCESSING 03_370787469.png ... *****
# ***** PROCESSING 03_370788469.png ... *****
# ***** PROCESSING 03_370789469.png ... *****
# ***** PROCESSING 03_371787469.png ... *****
# ***** PROCESSING 03_371788469.png ... *****
# ***** PROCESSING 03_371789469.png ... *****
# ***** PROCESSING 05_375793474.png ... *****
# COMBINING@boundary=4972
# ***** PROCESSING 05_375793475.png ... *****
# COMBINING@boundary=2700
# COMBINING@boundary=4950
# ***** PROCESSING 05_375793476.png ... *****
# COMBINING@boundary=3178
# COMBINING@boundary=4994
# ***** PROCESSING 05_375794474.png ... *****
# COMBINING@boundary=4580
# ***** PROCESSING 05_375794475.png ... *****
# COMBINING@boundary=2736
# COMBINING@boundary=4560
# COMBINING@boundary=5016
# ***** PROCESSING 05_375794476.png ... *****
# COMBINING@boundary=3248
# ***** PROCESSING 05_375795475.png ... *****
# COMBINING@boundary=2280
# COMBINING@boundary=2736
# ***** PROCESSING 05_375795476.png ... *****
# COMBINING@boundary=2742
# COMBINING@boundary=3199
# ***** PROCESSING 05_376793474.png ... *****
# COMBINING@boundary=4560
# ***** PROCESSING 05_376793475.png ... *****
# COMBINING@boundary=2290
# COMBINING@boundary=2748
# COMBINING@boundary=4580
# COMBINING@boundary=5038
# COMBINING@boundary=5954
# COMBINING@boundary=5954 (again)
# ***** PROCESSING 05_376794474.png ... *****
# COMBINING@boundary=5863
# ***** PROCESSING 05_376794475.png ... *****
# COMBINING@boundary=5941
# ***** PROCESSING 05_376794476.png ... *****
# COMBINING@boundary=2766
# COMBINING@boundary=3227
# ***** PROCESSING 05_376795474.png ... *****
# COMBINING@boundary=4590
# ***** PROCESSING 05_376795475.png ... *****
# COMBINING@boundary=2315
# COMBINING@boundary=2778
# COMBINING@boundary=5093
# COMBINING@boundary=6019
# ***** PROCESSING 05_376795476.png ... *****
# COMBINING@boundary=3248
# ***** PROCESSING 05_377794474.png ... *****
# COMBINING@boundary=1404
# COMBINING@boundary=2808
# COMBINING@boundary=6084
# ***** PROCESSING 05_377794475.png ... *****
# COMBINING@boundary=1401
# COMBINING@boundary=2802
# COMBINING@boundary=3269
# COMBINING@boundary=6071
# ***** PROCESSING 05_377794476.png ... *****
# COMBINING@boundary=6058
# ***** PROCESSING 05_377795475.png ... *****
# COMBINING@boundary=1422
# COMBINING@boundary=2844
# COMBINING@boundary=3318
# COMBINING@boundary=4266
# COMBINING@boundary=6162
# ***** PROCESSING 05_377795476.png ... *****
# ***** PROCESSING 06_378797478.png ... *****
# ***** PROCESSING 06_378798477.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=2838
# COMBINING@boundary=3784
# ***** PROCESSING 06_378798478.png ... *****
# COMBINING@boundary=3792
# ***** PROCESSING 06_378798479.png ... *****
# ***** PROCESSING 06_378799478.png ... *****
# COMBINING@boundary=2910
# ***** PROCESSING 06_378799479.png ... *****
# ***** PROCESSING 06_379797477.png ... *****
# COMBINING@boundary=3704
# COMBINING@boundary=6019
# ***** PROCESSING 06_379797478.png ... *****
# COMBINING@boundary=2862
# ***** PROCESSING 06_379798477.png ... *****
# COMBINING@boundary=1416
# COMBINING@boundary=2832
# COMBINING@boundary=3776
# ***** PROCESSING 06_379798478.png ... *****
# ***** PROCESSING 06_379798479.png ... *****
# ***** PROCESSING 06_379799478.png ... *****
# COMBINING@boundary=2844
# ***** PROCESSING 06_379799479.png ... *****
# COMBINING@boundary=2904
# ***** PROCESSING 06_380797478.png ... *****
# ***** PROCESSING 06_380798477.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=3325
# COMBINING@boundary=3800
# COMBINING@boundary=4750
# ***** PROCESSING 06_380798478.png ... *****
# ***** PROCESSING 06_380798479.png ... *****
# COMBINING@boundary=2886
# COMBINING@boundary=3367
# ***** PROCESSING 06_380799479.png ... *****
# COMBINING@boundary=2892
# COMBINING@boundary=3374
# ***** PROCESSING 07_381800480.png ... *****
# COMBINING@boundary=1904
# ***** PROCESSING 07_381800481.png ... *****
# COMBINING@boundary=1872
# COMBINING@boundary=4212
# ***** PROCESSING 07_381800482.png ... *****
# COMBINING@boundary=1856
# COMBINING@boundary=4176
# ***** PROCESSING 07_381801480.png ... *****
# COMBINING@boundary=1872
# COMBINING@boundary=3276
# ***** PROCESSING 07_381801481.png ... *****
# COMBINING@boundary=1880
# ***** PROCESSING 07_381801482.png ... *****
# COMBINING@boundary=1884
# COMBINING@boundary=3297
# COMBINING@boundary=4239
# ***** PROCESSING 07_382800480.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=4311
# ***** PROCESSING 07_382800481.png ... *****
# COMBINING@boundary=1924
# ***** PROCESSING 07_382800482.png ... *****
# COMBINING@boundary=1940
# ***** PROCESSING 07_382801480.png ... *****
# COMBINING@boundary=1884
# COMBINING@boundary=4239
# ***** PROCESSING 07_382801481.png ... *****
# COMBINING@boundary=1896
# COMBINING@boundary=4266
# ***** PROCESSING 07_382801482.png ... *****
# COMBINING@boundary=1888
# COMBINING@boundary=4248
# ***** PROCESSING 07_382802480.png ... *****
# COMBINING@boundary=1924
# ***** PROCESSING 07_382802481.png ... *****
# COMBINING@boundary=1904
# COMBINING@boundary=3332
# COMBINING@boundary=4284
# ***** PROCESSING 07_382802482.png ... *****
# COMBINING@boundary=1912
# ***** PROCESSING 07_383800480.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=4311
# ***** PROCESSING 07_383800481.png ... *****
# COMBINING@boundary=1896
# ***** PROCESSING 07_383800482.png ... *****
# COMBINING@boundary=1932
# ***** PROCESSING 07_383801480.png ... *****
# COMBINING@boundary=1904
# COMBINING@boundary=4284
# ***** PROCESSING 07_383801481.png ... *****
# COMBINING@boundary=1896
# COMBINING@boundary=3318
# COMBINING@boundary=4266
# ***** PROCESSING 07_383801482.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=4293
# ***** PROCESSING 07_383802481.png ... *****
# COMBINING@boundary=1924
# ***** PROCESSING 07_383802482.png ... *****
# COMBINING@boundary=1932
# ***** PROCESSING 08_383802483.png ... *****
# COMBINING@boundary=2844
# COMBINING@boundary=3318
# COMBINING@boundary=4266
# COMBINING@boundary=5214
# ***** PROCESSING 08_383802484.png ... *****
# COMBINING@boundary=1852
# ***** PROCESSING 08_383803483.png ... *****
# COMBINING@boundary=5225
# ***** PROCESSING 08_383803484.png ... *****
# COMBINING@boundary=4660
# ***** PROCESSING 08_383803485.png ... *****
# COMBINING@boundary=4640
# ***** PROCESSING 08_383804484.png ... *****
# COMBINING@boundary=2862
# COMBINING@boundary=4770
# ***** PROCESSING 08_383804485.png ... *****
# COMBINING@boundary=1908
# ***** PROCESSING 08_384802483.png ... *****
# COMBINING@boundary=1407
# COMBINING@boundary=4690
# COMBINING@boundary=6097
# ***** PROCESSING 08_384803483.png ... *****
# COMBINING@boundary=1416
# COMBINING@boundary=4720
# COMBINING@boundary=6136
# ***** PROCESSING 08_384803484.png ... *****
# COMBINING@boundary=1398
# COMBINING@boundary=3262
# COMBINING@boundary=5126
# COMBINING@boundary=6058
# COMBINING@boundary=6058 (again)
# ***** PROCESSING 08_384803485.png ... *****
# COMBINING@boundary=4131
# COMBINING@boundary=5967
# ***** PROCESSING 08_384804483.png ... *****
# ***** PROCESSING 08_385802483.png ... *****
# COMBINING@boundary=5258
# ***** PROCESSING 08_385802484.png ... *****
# COMBINING@boundary=1904
# COMBINING@boundary=5236
# ***** PROCESSING 08_385803483.png ... *****
# COMBINING@boundary=1948
# COMBINING@boundary=2922
# COMBINING@boundary=3409
# ***** PROCESSING 08_385803484.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=5269
# ***** PROCESSING 08_385803485.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=2856
# COMBINING@boundary=3332
# COMBINING@boundary=4284
# COMBINING@boundary=5236
# ***** PROCESSING 08_385804483.png ... *****
# COMBINING@boundary=3458
# COMBINING@boundary=5434
# ***** PROCESSING 08_385804484.png ... *****
# COMBINING@boundary=2946
# COMBINING@boundary=3437
# COMBINING@boundary=5401
# ***** PROCESSING 08_385804485.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=2916
# COMBINING@boundary=5346
# ***** PROCESSING 09_386804486.png ... *****
# COMBINING@boundary=2390
# COMBINING@boundary=2868
# COMBINING@boundary=3346
# COMBINING@boundary=3824
# COMBINING@boundary=4302
# COMBINING@boundary=4780
# ***** PROCESSING 09_386804487.png ... *****
# COMBINING@boundary=2400
# COMBINING@boundary=2880
# COMBINING@boundary=3840
# COMBINING@boundary=4320
# ***** PROCESSING 09_386806487.png ... *****
# COMBINING@boundary=2400
# COMBINING@boundary=4320
# COMBINING@boundary=4800
# ***** PROCESSING 09_387804485.png ... *****
# COMBINING@boundary=2325
# COMBINING@boundary=3255
# COMBINING@boundary=6045
# ***** PROCESSING 09_387805485.png ... *****
# COMBINING@boundary=2385
# COMBINING@boundary=3339
# COMBINING@boundary=4293
# ***** PROCESSING 09_387805486.png ... *****
# COMBINING@boundary=2400
# COMBINING@boundary=2880
# COMBINING@boundary=3360
# COMBINING@boundary=3840
# COMBINING@boundary=4320
# COMBINING@boundary=4800
# ***** PROCESSING 09_387805487.png ... *****
# COMBINING@boundary=2420
# COMBINING@boundary=2904
# ***** PROCESSING 09_387806485.png ... *****
# COMBINING@boundary=2375
# COMBINING@boundary=3325
# ***** PROCESSING 09_388806486.png ... *****
# COMBINING@boundary=2405
# COMBINING@boundary=3367
# COMBINING@boundary=4329
# COMBINING@boundary=4810
# ***** PROCESSING 09_388806487.png ... *****
# COMBINING@boundary=2415
# COMBINING@boundary=2898
# COMBINING@boundary=3381
# COMBINING@boundary=3864
# ***** PROCESSING 10_388807487.png ... *****
# COMBINING@boundary=1900
# COMBINING@boundary=3800
# COMBINING@boundary=4275
# COMBINING@boundary=4275 (again)
# COMBINING@boundary=4750
# ***** PROCESSING 10_388807488.png ... *****
# COMBINING@boundary=1924
# COMBINING@boundary=1924 (again)
# COMBINING@boundary=2405
# COMBINING@boundary=3848
# COMBINING@boundary=4329
# COMBINING@boundary=4810
# ***** PROCESSING 10_388808488.png ... *****
# COMBINING@boundary=1920
# COMBINING@boundary=3840
# COMBINING@boundary=4320
# COMBINING@boundary=4800
# ***** PROCESSING 10_389808488.png ... *****
# COMBINING@boundary=3888
# COMBINING@boundary=4374
# COMBINING@boundary=4860
# ***** PROCESSING 10_390808487.png ... *****
# COMBINING@boundary=1928
# COMBINING@boundary=3856
# COMBINING@boundary=4338
# COMBINING@boundary=4820
# ***** PROCESSING 10_390808488.png ... *****
# COMBINING@boundary=1948
# COMBINING@boundary=3896
# COMBINING@boundary=4383
# COMBINING@boundary=4870
# ***** PROCESSING 10_390808489.png ... *****
# COMBINING@boundary=3928
# COMBINING@boundary=4419
# COMBINING@boundary=4910
# ***** PROCESSING 11_390809490.png ... *****
# COMBINING@boundary=3832
# COMBINING@boundary=4311
# COMBINING@boundary=4790
# ***** PROCESSING 11_390809491.png ... *****
# COMBINING@boundary=3856
# COMBINING@boundary=4820
# ***** PROCESSING 11_390810490.png ... *****
# COMBINING@boundary=3768
# COMBINING@boundary=4239
# COMBINING@boundary=4710
# ***** PROCESSING 11_390810491.png ... *****
# COMBINING@boundary=2898
# COMBINING@boundary=4830
# ***** PROCESSING 11_390810492.png ... *****
# COMBINING@boundary=2880
# COMBINING@boundary=3360
# COMBINING@boundary=4800
# ***** PROCESSING 11_391809490.png ... *****
# COMBINING@boundary=3840
# ***** PROCESSING 11_391809491.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=3848
# ***** PROCESSING 11_391810490.png ... *****
# COMBINING@boundary=3776
# COMBINING@boundary=4720
# ***** PROCESSING 11_391810491.png ... *****
# COMBINING@boundary=2862
# COMBINING@boundary=4770
# ***** PROCESSING 11_391810492.png ... *****
# COMBINING@boundary=2862
# COMBINING@boundary=3339
# ***** PROCESSING 11_391811491.png ... *****
# COMBINING@boundary=4720
# ***** PROCESSING 11_391811492.png ... *****
# COMBINING@boundary=3768
# COMBINING@boundary=4710
# ***** PROCESSING 11_392809490.png ... *****
# COMBINING@boundary=3840
# COMBINING@boundary=4800
# ***** PROCESSING 11_392810490.png ... *****
# COMBINING@boundary=4720
# ***** PROCESSING 11_392810491.png ... *****
# COMBINING@boundary=2892
# COMBINING@boundary=3856
# COMBINING@boundary=4820
# ***** PROCESSING 11_392810492.png ... *****
# COMBINING@boundary=2898
# COMBINING@boundary=3864
# COMBINING@boundary=4830
# ***** PROCESSING 11_392811491.png ... *****
# COMBINING@boundary=2838
# COMBINING@boundary=3311
# ***** PROCESSING 12_392811492.png ... *****
# COMBINING@boundary=1389
# COMBINING@boundary=3704
# COMBINING@boundary=4167
# COMBINING@boundary=4630
# ***** PROCESSING 12_392812493.png ... *****
# COMBINING@boundary=1380
# COMBINING@boundary=3680
# COMBINING@boundary=4600
# ***** PROCESSING 12_393811492.png ... *****
# COMBINING@boundary=1386
# COMBINING@boundary=3234
# COMBINING@boundary=3696
# COMBINING@boundary=4158
# COMBINING@boundary=4620
# ***** PROCESSING 12_393812492.png ... *****
# COMBINING@boundary=3760
# COMBINING@boundary=4230
# COMBINING@boundary=4700
# ***** PROCESSING 12_393812493.png ... *****
# COMBINING@boundary=1392
# COMBINING@boundary=3712
# COMBINING@boundary=4640
# COMBINING@boundary=6032
# ***** PROCESSING 12_394811492.png ... *****
# COMBINING@boundary=1410
# COMBINING@boundary=3290
# COMBINING@boundary=3760
# COMBINING@boundary=4700
# ***** PROCESSING 12_394812492.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=3339
# COMBINING@boundary=3816
# COMBINING@boundary=4293
# COMBINING@boundary=4770
# ***** PROCESSING 12_394812493.png ... *****
# COMBINING@boundary=1413
# COMBINING@boundary=3297
# COMBINING@boundary=3768
# COMBINING@boundary=4239
# COMBINING@boundary=4710
# COMBINING@boundary=5181
# ***** PROCESSING 12_394813492.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=3864
# COMBINING@boundary=4830
# ***** PROCESSING 12_394813493.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3832
# COMBINING@boundary=4311
# COMBINING@boundary=4790
# ***** PROCESSING 12_394813494.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=3808
# COMBINING@boundary=4760
# ***** PROCESSING 13_394813493.png ... *****
# COMBINING@boundary=1392
# COMBINING@boundary=2320
# COMBINING@boundary=2784
# COMBINING@boundary=3712
# COMBINING@boundary=4640
# ***** PROCESSING 13_394813494.png ... *****
# COMBINING@boundary=2295
# COMBINING@boundary=2754
# COMBINING@boundary=4590
# ***** PROCESSING 13_395813493.png ... *****
# COMBINING@boundary=2365
# COMBINING@boundary=2838
# COMBINING@boundary=4257
# COMBINING@boundary=4730
# ***** PROCESSING 13_395813495.png ... *****
# COMBINING@boundary=1386
# COMBINING@boundary=2310
# COMBINING@boundary=2772
# COMBINING@boundary=3696
# COMBINING@boundary=4620
# COMBINING@boundary=6006
# ***** PROCESSING 13_395814493.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=2425
# COMBINING@boundary=2910
# COMBINING@boundary=4365
# ***** PROCESSING 13_395814495.png ... *****
# COMBINING@boundary=2345
# COMBINING@boundary=2814
# COMBINING@boundary=3752
# COMBINING@boundary=4221
# COMBINING@boundary=4690
# COMBINING@boundary=6097
# ***** PROCESSING 13_396813494.png ... *****
# COMBINING@boundary=2315
# COMBINING@boundary=2778
# COMBINING@boundary=3704
# COMBINING@boundary=4630
# ***** PROCESSING 13_396814493.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=2420
# COMBINING@boundary=2904
# COMBINING@boundary=3388
# COMBINING@boundary=3872
# COMBINING@boundary=4356
# ***** PROCESSING 13_396815495.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=2904
# COMBINING@boundary=3388
# COMBINING@boundary=4356
# ***** PROCESSING 14_396815496.png ... *****
# COMBINING@boundary=3220
# COMBINING@boundary=5060
# ***** PROCESSING 14_396815497.png ... *****
# COMBINING@boundary=3234
# COMBINING@boundary=3696
# COMBINING@boundary=4620
# ***** PROCESSING 14_397815496.png ... *****
# COMBINING@boundary=5049
# ***** PROCESSING 14_397816496.png ... *****
# COMBINING@boundary=2315
# COMBINING@boundary=3241
# COMBINING@boundary=3704
# COMBINING@boundary=5093
# COMBINING@boundary=6019
# ***** PROCESSING 14_397816497.png ... *****
# COMBINING@boundary=1407
# COMBINING@boundary=2814
# COMBINING@boundary=4690
# COMBINING@boundary=6097
# ***** PROCESSING 14_397816498.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=2904
# COMBINING@boundary=4356
# COMBINING@boundary=5324
# ***** PROCESSING 14_397817496.png ... *****
# COMBINING@boundary=1416
# COMBINING@boundary=2832
# COMBINING@boundary=6136
# ***** PROCESSING 14_397817497.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=2850
# COMBINING@boundary=4275
# ***** PROCESSING 14_398815496.png ... *****
# COMBINING@boundary=4590
# COMBINING@boundary=5049
# ***** PROCESSING 14_398816496.png ... *****
# COMBINING@boundary=1392
# COMBINING@boundary=2784
# COMBINING@boundary=3248
# COMBINING@boundary=3712
# COMBINING@boundary=4640
# ***** PROCESSING 14_398817496.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=2856
# COMBINING@boundary=5236
# ***** PROCESSING 15_398817499.png ... *****
# COMBINING@boundary=1407
# COMBINING@boundary=2814
# COMBINING@boundary=3283
# COMBINING@boundary=4690
# COMBINING@boundary=5159
# ***** PROCESSING 15_399817498.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=4329
# ***** PROCESSING 15_399818498.png ... *****
# COMBINING@boundary=1413
# COMBINING@boundary=2355
# COMBINING@boundary=3297
# ***** PROCESSING 15_400818498.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=5203
# ***** PROCESSING 17_402821501.png ... *****
# COMBINING@boundary=2285
# COMBINING@boundary=2742
# COMBINING@boundary=4570
# ***** PROCESSING 17_402821502.png ... *****
# ***** PROCESSING 17_402821503.png ... *****
# COMBINING@boundary=4580
# ***** PROCESSING 17_402822501.png ... *****
# COMBINING@boundary=926
# COMBINING@boundary=2315
# COMBINING@boundary=2778
# COMBINING@boundary=4630
# ***** PROCESSING 17_402822502.png ... *****
# COMBINING@boundary=2778
# ***** PROCESSING 17_402822503.png ... *****
# COMBINING@boundary=2315
# COMBINING@boundary=2778
# COMBINING@boundary=4630
# ***** PROCESSING 17_403821501.png ... *****
# COMBINING@boundary=2305
# ***** PROCESSING 17_403822501.png ... *****
# COMBINING@boundary=2355
# COMBINING@boundary=4239
# ***** PROCESSING 17_403822502.png ... *****
# COMBINING@boundary=6097
# ***** PROCESSING 17_403822503.png ... *****
# COMBINING@boundary=2350
# COMBINING@boundary=4700
# ***** PROCESSING 17_403823502.png ... *****
# COMBINING@boundary=4257
# ***** PROCESSING 17_403823503.png ... *****
# COMBINING@boundary=1904
# COMBINING@boundary=2380
# COMBINING@boundary=4760
# ***** PROCESSING 17_404821501.png ... *****
# COMBINING@boundary=1395
# COMBINING@boundary=2325
# ***** PROCESSING 17_404821502.png ... *****
# COMBINING@boundary=2315
# ***** PROCESSING 17_404821503.png ... *****
# COMBINING@boundary=2305
# COMBINING@boundary=2766
# ***** PROCESSING 17_404822501.png ... *****
# COMBINING@boundary=2380
# COMBINING@boundary=4760
# ***** PROCESSING 17_404822502.png ... *****
# COMBINING@boundary=4760
# ***** PROCESSING 17_404822503.png ... *****
# COMBINING@boundary=4248
# ***** PROCESSING 17_404823502.png ... *****
# COMBINING@boundary=4760
# ***** PROCESSING 17_404823503.png ... *****
# ***** PROCESSING 18_405823505.png ... *****
# COMBINING@boundary=2856
# ***** PROCESSING 18_405823506.png ... *****
# COMBINING@boundary=2892
# ***** PROCESSING 18_405824504.png ... *****
# COMBINING@boundary=2910
# ***** PROCESSING 18_405824505.png ... *****
# COMBINING@boundary=2886
# ***** PROCESSING 18_405824506.png ... *****
# ***** PROCESSING 18_405825506.png ... *****
# COMBINING@boundary=2868
# ***** PROCESSING 18_406823504.png ... *****
# COMBINING@boundary=2838
# ***** PROCESSING 18_406824504.png ... *****
# COMBINING@boundary=2904
# ***** PROCESSING 18_406824505.png ... *****
# COMBINING@boundary=2910
# COMBINING@boundary=4850
# ***** PROCESSING 18_406824506.png ... *****
# ***** PROCESSING 18_406825504.png ... *****
# COMBINING@boundary=2874
# ***** PROCESSING 18_406825505.png ... *****
# COMBINING@boundary=2850
# ***** PROCESSING 18_406825506.png ... *****
# COMBINING@boundary=2856
# ***** PROCESSING 18_407823504.png ... *****
# COMBINING@boundary=2850
# ***** PROCESSING 18_407824504.png ... *****
# COMBINING@boundary=2922
# COMBINING@boundary=4870
# ***** PROCESSING 18_407824505.png ... *****
# ***** PROCESSING 18_407824506.png ... *****
# ***** PROCESSING 18_407825504.png ... *****
# COMBINING@boundary=2874
# ***** PROCESSING 18_407825505.png ... *****
# COMBINING@boundary=2880
# ***** PROCESSING 18_407825506.png ... *****
# ***** PROCESSING 19_407825506.png ... *****
# COMBINING@boundary=1410
# COMBINING@boundary=3760
# ***** PROCESSING 19_407825507.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=2380
# COMBINING@boundary=2856
# ***** PROCESSING 19_407826506.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=2405
# COMBINING@boundary=2886
# ***** PROCESSING 19_407826507.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=2365
# COMBINING@boundary=2838
# ***** PROCESSING 19_407827507.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2400
# COMBINING@boundary=4320
# COMBINING@boundary=4800
# ***** PROCESSING 19_407827508.png ... *****
# COMBINING@boundary=1422
# COMBINING@boundary=2370
# COMBINING@boundary=2844
# ***** PROCESSING 19_408826506.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=2898
# COMBINING@boundary=4830
# ***** PROCESSING 19_408826507.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=2405
# COMBINING@boundary=2886
# ***** PROCESSING 19_408827506.png ... *****
# COMBINING@boundary=1434
# COMBINING@boundary=2390
# COMBINING@boundary=2868
# ***** PROCESSING 19_408827507.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=2420
# COMBINING@boundary=2420 (again)
# COMBINING@boundary=2904
# COMBINING@boundary=4356
# COMBINING@boundary=4840
# ***** PROCESSING 19_408827508.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=2365
# COMBINING@boundary=2838
# ***** PROCESSING 19_409827506.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=2380
# ***** PROCESSING 19_409827507.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=2410
# COMBINING@boundary=2892
# ***** PROCESSING 19_409827508.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=2405
# COMBINING@boundary=4329
# COMBINING@boundary=4810
# ***** PROCESSING 20_409828508.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=3816
# COMBINING@boundary=4293
# COMBINING@boundary=4770
# ***** PROCESSING 20_409828509.png ... *****
# COMBINING@boundary=1944
# COMBINING@boundary=3888
# COMBINING@boundary=4860
# COMBINING@boundary=5346
# ***** PROCESSING 20_409828510.png ... *****
# COMBINING@boundary=1884
# COMBINING@boundary=3768
# COMBINING@boundary=4239
# COMBINING@boundary=5181
# ***** PROCESSING 20_410828508.png ... *****
# COMBINING@boundary=1924
# COMBINING@boundary=4810
# COMBINING@boundary=5291
# ***** PROCESSING 20_410828509.png ... *****
# COMBINING@boundary=4374
# COMBINING@boundary=5346
# ***** PROCESSING 20_410828510.png ... *****
# COMBINING@boundary=3800
# COMBINING@boundary=4750
# COMBINING@boundary=5225
# ***** PROCESSING 20_410829509.png ... *****
# COMBINING@boundary=1912
# COMBINING@boundary=3824
# COMBINING@boundary=4780
# COMBINING@boundary=5258
# ***** PROCESSING 20_410829510.png ... *****
# COMBINING@boundary=1892
# COMBINING@boundary=3784
# COMBINING@boundary=4257
# ***** PROCESSING 20_410830510.png ... *****
# COMBINING@boundary=1936
# COMBINING@boundary=4840
# COMBINING@boundary=5324
# ***** PROCESSING 20_411828510.png ... *****
# COMBINING@boundary=1912
# COMBINING@boundary=3824
# COMBINING@boundary=4780
# COMBINING@boundary=5258
# ***** PROCESSING 20_411829509.png ... *****
# COMBINING@boundary=1928
# COMBINING@boundary=3856
# COMBINING@boundary=4338
# COMBINING@boundary=4820
# COMBINING@boundary=5302
# ***** PROCESSING 20_411829510.png ... *****
# COMBINING@boundary=3832
# COMBINING@boundary=4311
# COMBINING@boundary=4790
# ***** PROCESSING 20_411830510.png ... *****
# COMBINING@boundary=5346
# ***** PROCESSING 21_411830510.png ... *****
# COMBINING@boundary=3332
# COMBINING@boundary=5236
# ***** PROCESSING 21_411830511.png ... *****
# COMBINING@boundary=2892
# ***** PROCESSING 21_411831511.png ... *****
# ***** PROCESSING 21_412830510.png ... *****
# COMBINING@boundary=5247
# ***** PROCESSING 21_412830511.png ... *****
# ***** PROCESSING 21_412831511.png ... *****
# COMBINING@boundary=3374
# COMBINING@boundary=3856
# COMBINING@boundary=4338
# COMBINING@boundary=4820
# ***** PROCESSING 21_413831510.png ... *****
# COMBINING@boundary=2844
# COMBINING@boundary=5214
# ***** PROCESSING 21_413831512.png ... *****
# ***** PROCESSING 22_413832512.png ... *****
# COMBINING@boundary=2380
# COMBINING@boundary=2856
# ***** PROCESSING 22_414832513.png ... *****
# COMBINING@boundary=1932
# COMBINING@boundary=2415
# ***** PROCESSING 22_414832514.png ... *****
# COMBINING@boundary=2430
# COMBINING@boundary=2916
# ***** PROCESSING 22_414833514.png ... *****
# COMBINING@boundary=2430
# COMBINING@boundary=3888
# ***** PROCESSING 23_415834514.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=2385
# COMBINING@boundary=3816
# COMBINING@boundary=4293
# ***** PROCESSING 23_415834515.png ... *****
# COMBINING@boundary=2415
# COMBINING@boundary=2898
# ***** PROCESSING 23_416834514.png ... *****
# COMBINING@boundary=1924
# COMBINING@boundary=2405
# COMBINING@boundary=2886
# COMBINING@boundary=5291
# ***** PROCESSING 23_416834515.png ... *****
# COMBINING@boundary=2405
# COMBINING@boundary=2886
# COMBINING@boundary=5291
# ***** PROCESSING 23_416835516.png ... *****
# COMBINING@boundary=2420
# COMBINING@boundary=2904
# ***** PROCESSING 23_417834515.png ... *****
# COMBINING@boundary=2892
# ***** PROCESSING 23_417835515.png ... *****
# COMBINING@boundary=2420
# COMBINING@boundary=2904
# COMBINING@boundary=5324
# ***** PROCESSING 23_417835516.png ... *****
# COMBINING@boundary=2410
# COMBINING@boundary=2892
# COMBINING@boundary=5302
# ***** PROCESSING 23_417836516.png ... *****
# COMBINING@boundary=2856
# COMBINING@boundary=5236
# ***** PROCESSING 24_417836516.png ... *****
# COMBINING@boundary=2340
# COMBINING@boundary=2808
# COMBINING@boundary=4212
# COMBINING@boundary=5148
# ***** PROCESSING 24_417836517.png ... *****
# COMBINING@boundary=1467
# COMBINING@boundary=2934
# COMBINING@boundary=3912
# COMBINING@boundary=4401
# ***** PROCESSING 24_417836518.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=1960
# COMBINING@boundary=2940
# COMBINING@boundary=3430
# COMBINING@boundary=4410
# ***** PROCESSING 24_417837517.png ... *****
# COMBINING@boundary=2385
# COMBINING@boundary=2862
# COMBINING@boundary=4293
# COMBINING@boundary=4770
# COMBINING@boundary=5247
# ***** PROCESSING 24_417837518.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2898
# COMBINING@boundary=3864
# COMBINING@boundary=4347
# ***** PROCESSING 24_418836516.png ... *****
# COMBINING@boundary=2355
# COMBINING@boundary=2826
# COMBINING@boundary=4710
# COMBINING@boundary=5181
# COMBINING@boundary=6123
# ***** PROCESSING 24_418836517.png ... *****
# COMBINING@boundary=1461
# COMBINING@boundary=2922
# COMBINING@boundary=3896
# ***** PROCESSING 24_418836518.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=2892
# ***** PROCESSING 24_418837517.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2880
# COMBINING@boundary=3840
# COMBINING@boundary=4320
# ***** PROCESSING 24_418837518.png ... *****
# COMBINING@boundary=1413
# COMBINING@boundary=2826
# COMBINING@boundary=3768
# COMBINING@boundary=4710
# COMBINING@boundary=5181
# ***** PROCESSING 24_418838518.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=2425
# COMBINING@boundary=2910
# COMBINING@boundary=3880
# COMBINING@boundary=4850
# COMBINING@boundary=5335
# ***** PROCESSING 24_419836517.png ... *****
# COMBINING@boundary=2415
# COMBINING@boundary=2898
# COMBINING@boundary=4830
# ***** PROCESSING 24_419837516.png ... *****
# COMBINING@boundary=2355
# COMBINING@boundary=2826
# COMBINING@boundary=4239
# COMBINING@boundary=5181
# ***** PROCESSING 24_419837517.png ... *****
# COMBINING@boundary=2395
# COMBINING@boundary=2874
# COMBINING@boundary=3832
# COMBINING@boundary=4790
# COMBINING@boundary=5269
# ***** PROCESSING 24_419837518.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=2910
# COMBINING@boundary=3880
# COMBINING@boundary=4365
# ***** PROCESSING 24_419838518.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=2940
# COMBINING@boundary=3920
# COMBINING@boundary=4410
# ***** PROCESSING 25_419838518.png ... *****
# COMBINING@boundary=1944
# COMBINING@boundary=3402
# COMBINING@boundary=3888
# COMBINING@boundary=4860
# COMBINING@boundary=5346
# ***** PROCESSING 25_419838519.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=1932
# COMBINING@boundary=2898
# COMBINING@boundary=3381
# COMBINING@boundary=3864
# COMBINING@boundary=4830
# COMBINING@boundary=5313
# ***** PROCESSING 25_419838520.png ... *****
# COMBINING@boundary=1467
# COMBINING@boundary=1956
# COMBINING@boundary=2934
# COMBINING@boundary=3423
# COMBINING@boundary=3912
# COMBINING@boundary=4890
# ***** PROCESSING 26_421840520.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=2420
# COMBINING@boundary=4840
# ***** PROCESSING 26_421840521.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2400
# COMBINING@boundary=4800
# COMBINING@boundary=5280
# ***** PROCESSING 26_421841522.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=4830
# COMBINING@boundary=5313
# ***** PROCESSING 26_422840520.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=3880
# COMBINING@boundary=4850
# COMBINING@boundary=5335
# ***** PROCESSING 26_422840521.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=3856
# COMBINING@boundary=4820
# COMBINING@boundary=5302
# ***** PROCESSING 26_422841521.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=2450
# COMBINING@boundary=2940
# ***** PROCESSING 26_422841522.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=2425
# COMBINING@boundary=4850
# ***** PROCESSING 26_423840520.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=5390
# ***** PROCESSING 26_423841521.png ... *****
# COMBINING@boundary=1479
# COMBINING@boundary=3944
# COMBINING@boundary=4437
# COMBINING@boundary=4930
# COMBINING@boundary=5423
# ***** PROCESSING 26_423841522.png ... *****
# COMBINING@boundary=1485
# COMBINING@boundary=2475
# COMBINING@boundary=4950
# ***** PROCESSING 27_423841522.png ... *****
# COMBINING@boundary=952
# COMBINING@boundary=2856
# ***** PROCESSING 27_423841523.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=4347
# ***** PROCESSING 27_423842522.png ... *****
# COMBINING@boundary=956
# ***** PROCESSING 27_423842523.png ... *****
# COMBINING@boundary=972
# ***** PROCESSING 27_423842524.png ... *****
# COMBINING@boundary=976
# COMBINING@boundary=4392
# ***** PROCESSING 27_423843522.png ... *****
# COMBINING@boundary=952
# ***** PROCESSING 27_423843523.png ... *****
# COMBINING@boundary=976
# COMBINING@boundary=3416
# COMBINING@boundary=4392
# ***** PROCESSING 27_423843524.png ... *****
# COMBINING@boundary=982
# COMBINING@boundary=2946
# COMBINING@boundary=3437
# COMBINING@boundary=4419
# ***** PROCESSING 27_424841523.png ... *****
# COMBINING@boundary=970
# COMBINING@boundary=4365
# ***** PROCESSING 27_424842522.png ... *****
# COMBINING@boundary=956
# ***** PROCESSING 27_424842523.png ... *****
# COMBINING@boundary=976
# COMBINING@boundary=1464
# COMBINING@boundary=4392
# ***** PROCESSING 27_424842524.png ... *****
# COMBINING@boundary=980
# COMBINING@boundary=4410
# ***** PROCESSING 27_424843522.png ... *****
# COMBINING@boundary=930
# ***** PROCESSING 27_424843523.png ... *****
# COMBINING@boundary=956
# COMBINING@boundary=4302
# ***** PROCESSING 27_424843524.png ... *****
# COMBINING@boundary=960
# COMBINING@boundary=2880
# COMBINING@boundary=3360
# COMBINING@boundary=4320
# ***** PROCESSING 27_425842523.png ... *****
# COMBINING@boundary=964
# ***** PROCESSING 27_425843523.png ... *****
# COMBINING@boundary=948
# COMBINING@boundary=4266
# ***** PROCESSING 27_425843524.png ... *****
# COMBINING@boundary=960
# COMBINING@boundary=3360
# COMBINING@boundary=4320
# ***** PROCESSING 28_425843524.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=2838
# ***** PROCESSING 28_425843525.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3832
# ***** PROCESSING 28_425844524.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2880
# COMBINING@boundary=3840
# ***** PROCESSING 28_425844525.png ... *****
# COMBINING@boundary=1467
# ***** PROCESSING 28_425844526.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=2862
# ***** PROCESSING 28_425845524.png ... *****
# COMBINING@boundary=1434
# COMBINING@boundary=2390
# ***** PROCESSING 28_425845525.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2880
# COMBINING@boundary=3840
# ***** PROCESSING 28_425845526.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=2850
# ***** PROCESSING 28_426843524.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=3848
# COMBINING@boundary=5291
# ***** PROCESSING 28_426843525.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=3856
# COMBINING@boundary=5302
# ***** PROCESSING 28_426844524.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=3872
# ***** PROCESSING 28_426844525.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=3872
# COMBINING@boundary=5324
# ***** PROCESSING 28_426844526.png ... *****
# COMBINING@boundary=1428
# COMBINING@boundary=2856
# ***** PROCESSING 28_426845525.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=3920
# ***** PROCESSING 28_426845526.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=3840
# ***** PROCESSING 28_427843524.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=1900
# COMBINING@boundary=2375
# COMBINING@boundary=3800
# COMBINING@boundary=5225
# ***** PROCESSING 28_427844525.png ... *****
# COMBINING@boundary=1461
# COMBINING@boundary=3896
# ***** PROCESSING 28_427844526.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=2892
# ***** PROCESSING 28_427845524.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=2940
# ***** PROCESSING 28_427845525.png ... *****
# COMBINING@boundary=1482
# COMBINING@boundary=3952
# COMBINING@boundary=5434
# ***** PROCESSING 28_427845526.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=1908
# ***** PROCESSING 29_427845526.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# ***** PROCESSING 29_427846526.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=3840
# COMBINING@boundary=4800
# ***** PROCESSING 29_427846527.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=2415 (again)
# COMBINING@boundary=2898
# ***** PROCESSING 29_427846528.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=2430
# COMBINING@boundary=2916
# COMBINING@boundary=4374
# ***** PROCESSING 29_427847527.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=2425
# COMBINING@boundary=2910
# COMBINING@boundary=3880
# COMBINING@boundary=5335
# ***** PROCESSING 29_427847528.png ... *****
# COMBINING@boundary=1467
# COMBINING@boundary=3912
# ***** PROCESSING 29_428845526.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=2410
# COMBINING@boundary=3856
# ***** PROCESSING 29_428846526.png ... *****
# COMBINING@boundary=1467
# COMBINING@boundary=2445
# COMBINING@boundary=2445 (again)
# COMBINING@boundary=3912
# ***** PROCESSING 29_428846527.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=3864
# ***** PROCESSING 29_428846528.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=3864
# COMBINING@boundary=5313
# ***** PROCESSING 29_428847526.png ... *****
# COMBINING@boundary=1455
# COMBINING@boundary=3880
# COMBINING@boundary=4850
# ***** PROCESSING 29_428847528.png ... *****
# COMBINING@boundary=1467
# COMBINING@boundary=2934
# ***** PROCESSING 29_429846528.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=2385
# COMBINING@boundary=2385 (again)
# COMBINING@boundary=3816
# ***** PROCESSING 29_429847526.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=3856
# ***** PROCESSING 29_429847528.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=2430
# COMBINING@boundary=2430 (again)
# ***** PROCESSING 30_429848528.png ... *****
# COMBINING@boundary=1936
# COMBINING@boundary=5324
# ***** PROCESSING 30_429848529.png ... *****
# COMBINING@boundary=1920
# COMBINING@boundary=2400
# COMBINING@boundary=3840
# COMBINING@boundary=5280
# ***** PROCESSING 30_429848530.png ... *****
# COMBINING@boundary=1936
# COMBINING@boundary=4356
# COMBINING@boundary=5324
# ***** PROCESSING 30_429849529.png ... *****
# COMBINING@boundary=1888
# COMBINING@boundary=3776
# ***** PROCESSING 30_429849530.png ... *****
# COMBINING@boundary=1904
# COMBINING@boundary=2380
# COMBINING@boundary=3332
# COMBINING@boundary=5236
# ***** PROCESSING 30_429850530.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=2430
# ***** PROCESSING 30_430848528.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=3816
# COMBINING@boundary=5247
# ***** PROCESSING 30_430848529.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=1928
# COMBINING@boundary=5302
# ***** PROCESSING 30_430848530.png ... *****
# COMBINING@boundary=1461
# COMBINING@boundary=1948
# COMBINING@boundary=2435
# COMBINING@boundary=3896
# COMBINING@boundary=5357
# ***** PROCESSING 30_430849529.png ... *****
# COMBINING@boundary=1413
# COMBINING@boundary=1884
# COMBINING@boundary=3768
# ***** PROCESSING 30_430849530.png ... *****
# COMBINING@boundary=1948
# COMBINING@boundary=2435
# COMBINING@boundary=3409
# ***** PROCESSING 30_430850529.png ... *****
# COMBINING@boundary=1416
# COMBINING@boundary=2360
# COMBINING@boundary=3304
# COMBINING@boundary=3776
# COMBINING@boundary=5192
# ***** PROCESSING 30_430850530.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=2395
# ***** PROCESSING 30_431848528.png ... *****
# COMBINING@boundary=1920
# COMBINING@boundary=5280
# ***** PROCESSING 30_431849529.png ... *****
# COMBINING@boundary=1410
# COMBINING@boundary=1880
# COMBINING@boundary=5170
# ***** PROCESSING 30_431849530.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=1924
# COMBINING@boundary=2405
# COMBINING@boundary=3367
# COMBINING@boundary=5291
# ***** PROCESSING 30_431850530.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=2415
# COMBINING@boundary=3864
# ***** PROCESSING 31_431850530.png ... *****
# COMBINING@boundary=1912
# COMBINING@boundary=3824
# COMBINING@boundary=4780
# COMBINING@boundary=5258
# COMBINING@boundary=5258 (again)
# ***** PROCESSING 31_431850531.png ... *****
# COMBINING@boundary=3768
# ***** PROCESSING 31_431851530.png ... *****
# COMBINING@boundary=3776
# COMBINING@boundary=4720
# ***** PROCESSING 31_431851531.png ... *****
# COMBINING@boundary=3840
# COMBINING@boundary=4800
# ***** PROCESSING 31_431851532.png ... *****
# COMBINING@boundary=1892
# COMBINING@boundary=3784
# COMBINING@boundary=4257
# COMBINING@boundary=4730
# ***** PROCESSING 31_431852531.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=3832
# COMBINING@boundary=4790
# COMBINING@boundary=5269
# ***** PROCESSING 31_431852532.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=3832
# COMBINING@boundary=4790
# COMBINING@boundary=5269
# ***** PROCESSING 31_432850530.png ... *****
# COMBINING@boundary=1912
# COMBINING@boundary=3824
# COMBINING@boundary=4780
# COMBINING@boundary=5258
# ***** PROCESSING 31_432850531.png ... *****
# COMBINING@boundary=3776
# ***** PROCESSING 31_432850532.png ... *****
# COMBINING@boundary=1888
# COMBINING@boundary=3776
# COMBINING@boundary=4720
# ***** PROCESSING 31_432851530.png ... *****
# COMBINING@boundary=3768
# ***** PROCESSING 31_432851531.png ... *****
# COMBINING@boundary=1912
# COMBINING@boundary=3824
# COMBINING@boundary=4780
# ***** PROCESSING 31_432851532.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=1908
# COMBINING@boundary=3816
# COMBINING@boundary=4770
# ***** PROCESSING 31_432852532.png ... *****
# COMBINING@boundary=1446
# COMBINING@boundary=1928
# ***** PROCESSING 31_433850530.png ... *****
# COMBINING@boundary=3800
# COMBINING@boundary=4275
# COMBINING@boundary=4750
# ***** PROCESSING 31_433850531.png ... *****
# COMBINING@boundary=1880
# COMBINING@boundary=3760
# ***** PROCESSING 31_433851530.png ... *****
# ***** PROCESSING 31_433851531.png ... *****
# COMBINING@boundary=1916
# COMBINING@boundary=3832
# COMBINING@boundary=4790
# ***** PROCESSING 31_433851532.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=3816
# COMBINING@boundary=4770
# COMBINING@boundary=5247
# ***** PROCESSING 31_433852531.png ... *****
# COMBINING@boundary=1928
# COMBINING@boundary=3856
# COMBINING@boundary=4820
# ***** PROCESSING 31_433852532.png ... *****
# COMBINING@boundary=1944
# COMBINING@boundary=2916
# COMBINING@boundary=3402
# ***** PROCESSING 32_433852532.png ... *****
# ***** PROCESSING 32_433852533.png ... *****
# ***** PROCESSING 32_433853532.png ... *****
# COMBINING@boundary=1908
# COMBINING@boundary=2385
# ***** PROCESSING 32_433853533.png ... *****
# ***** PROCESSING 32_434852532.png ... *****
# COMBINING@boundary=1892
# COMBINING@boundary=2365
# ***** PROCESSING 32_434853532.png ... *****
# ***** PROCESSING 32_434853533.png ... *****
# ***** PROCESSING 32_434853534.png ... *****
# ***** PROCESSING 32_435852533.png ... *****
# ***** PROCESSING 32_435853532.png ... *****
# ***** PROCESSING 32_435853533.png ... *****
# COMBINING@boundary=5203
# ***** PROCESSING 32_435853534.png ... *****
# ***** PROCESSING 32_435854534.png ... *****
# ***** PROCESSING 33_435854534.png ... *****
# COMBINING@boundary=1844
# ***** PROCESSING 33_435854535.png ... *****
# ***** PROCESSING 33_435855535.png ... *****
# COMBINING@boundary=3339
# ***** PROCESSING 33_435855536.png ... *****
# ***** PROCESSING 33_436854534.png ... *****
# COMBINING@boundary=5967
# COMBINING@boundary=5967 (again)
# ***** PROCESSING 33_436854535.png ... *****
# ***** PROCESSING 33_436855536.png ... *****
# ***** PROCESSING 33_437855536.png ... *****
# ***** PROCESSING 34_437856536.png ... *****
# COMBINING@boundary=1864
# COMBINING@boundary=3728
# ***** PROCESSING 34_437856538.png ... *****
# COMBINING@boundary=3768
# COMBINING@boundary=4239
# ***** PROCESSING 34_438856537.png ... *****
# ***** PROCESSING 34_438857537.png ... *****
# COMBINING@boundary=1924
# ***** PROCESSING 34_438857538.png ... *****
# COMBINING@boundary=1944
# COMBINING@boundary=3402
# ***** PROCESSING 34_439856537.png ... *****
# COMBINING@boundary=1864
# COMBINING@boundary=3728
# ***** PROCESSING 35_439858538.png ... *****
# COMBINING@boundary=3248
# ***** PROCESSING 35_439858539.png ... *****
# ***** PROCESSING 35_439859538.png ... *****
# ***** PROCESSING 35_439859540.png ... *****
# COMBINING@boundary=3213
# ***** PROCESSING 35_440858538.png ... *****
# ***** PROCESSING 35_440859538.png ... *****
# COMBINING@boundary=3262
# ***** PROCESSING 35_440859539.png ... *****
# ***** PROCESSING 35_440859540.png ... *****
# COMBINING@boundary=3255
# ***** PROCESSING 35_441858538.png ... *****
# ***** PROCESSING 35_441859538.png ... *****
# COMBINING@boundary=2360
# COMBINING@boundary=3304
# ***** PROCESSING 35_441860539.png ... *****
# COMBINING@boundary=4266
# COMBINING@boundary=4740
# ***** PROCESSING 35_441860540.png ... *****
# COMBINING@boundary=4840
# ***** PROCESSING 36_441860540.png ... *****
# ***** PROCESSING 36_441860541.png ... *****
# ***** PROCESSING 36_441860542.png ... *****
# COMBINING@boundary=2916
# COMBINING@boundary=3888
# ***** PROCESSING 36_442860540.png ... *****
# COMBINING@boundary=4176
# COMBINING@boundary=5104
# ***** PROCESSING 36_442860541.png ... *****
# ***** PROCESSING 36_442860542.png ... *****
# COMBINING@boundary=2850
# ***** PROCESSING 36_442861541.png ... *****
# ***** PROCESSING 36_442861542.png ... *****
# ***** PROCESSING 36_443861541.png ... *****
# ***** PROCESSING 36_443861542.png ... *****
# COMBINING@boundary=2850
# ***** PROCESSING 37_442861541.png ... *****
# COMBINING@boundary=1864
# COMBINING@boundary=3728
# COMBINING@boundary=5126
# ***** PROCESSING 37_442861542.png ... *****
# COMBINING@boundary=1880
# COMBINING@boundary=3760
# COMBINING@boundary=4700
# ***** PROCESSING 37_442861543.png ... *****
# COMBINING@boundary=3744
# COMBINING@boundary=5148
# ***** PROCESSING 37_442862541.png ... *****
# COMBINING@boundary=1872
# COMBINING@boundary=3744
# ***** PROCESSING 37_442862542.png ... *****
# COMBINING@boundary=3374
# COMBINING@boundary=4338
# COMBINING@boundary=4820
# ***** PROCESSING 37_442862543.png ... *****
# COMBINING@boundary=3304
# COMBINING@boundary=3776
# ***** PROCESSING 37_443861541.png ... *****
# COMBINING@boundary=1848
# COMBINING@boundary=3234
# COMBINING@boundary=4620
# COMBINING@boundary=6006
# ***** PROCESSING 37_443861542.png ... *****
# COMBINING@boundary=3784
# ***** PROCESSING 37_443862541.png ... *****
# COMBINING@boundary=1888
# COMBINING@boundary=3776
# ***** PROCESSING 37_443862542.png ... *****
# COMBINING@boundary=3339
# COMBINING@boundary=4770
# ***** PROCESSING 37_443862543.png ... *****
# COMBINING@boundary=3311
# ***** PROCESSING 37_443863543.png ... *****
# COMBINING@boundary=2892
# ***** PROCESSING 37_444861541.png ... *****
# COMBINING@boundary=1872
# COMBINING@boundary=3744
# COMBINING@boundary=4680
# ***** PROCESSING 37_444861542.png ... *****
# COMBINING@boundary=3792
# COMBINING@boundary=4740
# ***** PROCESSING 37_444861543.png ... *****
# COMBINING@boundary=3311
# COMBINING@boundary=3784
# COMBINING@boundary=4730
# ***** PROCESSING 37_444862542.png ... *****
# COMBINING@boundary=3353
# COMBINING@boundary=4311
# COMBINING@boundary=4790
# ***** PROCESSING 37_444862543.png ... *****
# COMBINING@boundary=3290
# COMBINING@boundary=3760
# COMBINING@boundary=4700
# ***** PROCESSING 37_444863543.png ... *****
# COMBINING@boundary=2904
# ***** PROCESSING 38_444862543.png ... *****
# COMBINING@boundary=1419
# COMBINING@boundary=3311
# ***** PROCESSING 38_444862544.png ... *****
# COMBINING@boundary=1398
# COMBINING@boundary=4660
# ***** PROCESSING 38_444863543.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=3339
# COMBINING@boundary=4770
# ***** PROCESSING 38_444863544.png ... *****
# COMBINING@boundary=1398
# COMBINING@boundary=3262
# ***** PROCESSING 38_444863545.png ... *****
# COMBINING@boundary=1389
# ***** PROCESSING 38_445862543.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=3325
# ***** PROCESSING 38_445862544.png ... *****
# COMBINING@boundary=1401
# COMBINING@boundary=3269
# ***** PROCESSING 38_445863543.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3353
# COMBINING@boundary=4790
# ***** PROCESSING 38_445863544.png ... *****
# COMBINING@boundary=1413
# COMBINING@boundary=3297
# ***** PROCESSING 38_445863545.png ... *****
# COMBINING@boundary=1404
# COMBINING@boundary=3276
# ***** PROCESSING 38_445864543.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=3388
# COMBINING@boundary=4840
# ***** PROCESSING 38_445864544.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=2880
# COMBINING@boundary=3360
# COMBINING@boundary=4800
# ***** PROCESSING 38_445864545.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=3325
# ***** PROCESSING 38_446863543.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3353
# COMBINING@boundary=4790
# ***** PROCESSING 38_446864543.png ... *****
# COMBINING@boundary=2380
# ***** PROCESSING 38_446864544.png ... *****
# COMBINING@boundary=1443
# COMBINING@boundary=3367
# COMBINING@boundary=3848
# COMBINING@boundary=4810
# ***** PROCESSING 38_446864545.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=3388
# COMBINING@boundary=3872
# COMBINING@boundary=4840
# ***** PROCESSING 39_445865545.png ... *****
# COMBINING@boundary=1928
# COMBINING@boundary=2410
# COMBINING@boundary=3374
# COMBINING@boundary=3856
# ***** PROCESSING 39_446865545.png ... *****
# COMBINING@boundary=1920
# COMBINING@boundary=2400
# COMBINING@boundary=3840
# ***** PROCESSING 39_446865546.png ... *****
# COMBINING@boundary=1896
# COMBINING@boundary=2370
# COMBINING@boundary=3792
# COMBINING@boundary=4266
# ***** PROCESSING 39_446866547.png ... *****
# COMBINING@boundary=960
# COMBINING@boundary=1920
# COMBINING@boundary=2400
# ***** PROCESSING 39_447865546.png ... *****
# COMBINING@boundary=1924
# COMBINING@boundary=2405
# COMBINING@boundary=3367
# COMBINING@boundary=3848
# ***** PROCESSING 39_447865547.png ... *****
# ***** PROCESSING 39_447866545.png ... *****
# COMBINING@boundary=1944
# COMBINING@boundary=2430
# COMBINING@boundary=3888
# ***** PROCESSING 39_447866546.png ... *****
# COMBINING@boundary=1932
# COMBINING@boundary=2415
# COMBINING@boundary=3864
# ***** PROCESSING 39_447866547.png ... *****
# COMBINING@boundary=972
# COMBINING@boundary=1944
# COMBINING@boundary=2430
# COMBINING@boundary=3402
# COMBINING@boundary=3888
# ***** PROCESSING 40_447866547.png ... *****
# COMBINING@boundary=1470
# COMBINING@boundary=3920
# COMBINING@boundary=4410
# ***** PROCESSING 40_447867548.png ... *****
# COMBINING@boundary=1440
# COMBINING@boundary=3360
# COMBINING@boundary=3840
# COMBINING@boundary=4320
# ***** PROCESSING 40_448866548.png ... *****
# COMBINING@boundary=4365
# ***** PROCESSING 40_449867547.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=3888
# COMBINING@boundary=4374
# ***** PROCESSING 40_449867548.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=3864
# COMBINING@boundary=4347
# ***** PROCESSING 41_448867547.png ... *****
# COMBINING@boundary=3353
# COMBINING@boundary=3832
# ***** PROCESSING 41_448867548.png ... *****
# COMBINING@boundary=1912
# ***** PROCESSING 41_448868549.png ... *****
# ***** PROCESSING 41_449867547.png ... *****
# COMBINING@boundary=3880
# ***** PROCESSING 41_449867548.png ... *****
# COMBINING@boundary=1924
# ***** PROCESSING 41_449868549.png ... *****
# COMBINING@boundary=3888
# ***** PROCESSING 41_449869549.png ... *****
# COMBINING@boundary=3920
# ***** PROCESSING 41_450867547.png ... *****
# ***** PROCESSING 41_450867548.png ... *****
# COMBINING@boundary=3816
# ***** PROCESSING 41_450868548.png ... *****
# COMBINING@boundary=1928
# COMBINING@boundary=4820
# ***** PROCESSING 41_450869549.png ... *****
# ***** PROCESSING 42_450868549.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3832
# ***** PROCESSING 42_450868550.png ... *****
# COMBINING@boundary=1431
# COMBINING@boundary=1908
# COMBINING@boundary=4770
# ***** PROCESSING 42_450869549.png ... *****
# COMBINING@boundary=1437
# COMBINING@boundary=3832
# COMBINING@boundary=4790
# ***** PROCESSING 42_450869550.png ... *****
# COMBINING@boundary=1458
# ***** PROCESSING 42_450870549.png ... *****
# COMBINING@boundary=1410
# COMBINING@boundary=2820
# COMBINING@boundary=3760
# ***** PROCESSING 42_451869549.png ... *****
# COMBINING@boundary=1422
# COMBINING@boundary=2844
# COMBINING@boundary=3792
# COMBINING@boundary=4740
# ***** PROCESSING 42_451869550.png ... *****
# COMBINING@boundary=1449
# ***** PROCESSING 42_451870549.png ... *****
# COMBINING@boundary=1425
# COMBINING@boundary=3800
# COMBINING@boundary=4750
# ***** PROCESSING 42_451870550.png ... *****
# COMBINING@boundary=1473
# COMBINING@boundary=4419
# ***** PROCESSING 42_451870551.png ... *****
# COMBINING@boundary=1458
# COMBINING@boundary=4374
# ***** PROCESSING 42_452870550.png ... *****
# COMBINING@boundary=1461
# COMBINING@boundary=4383
# ***** PROCESSING 42_452870551.png ... *****
# COMBINING@boundary=1449
# ***** PROCESSING 43_451870550.png ... *****
# COMBINING@boundary=1920
# COMBINING@boundary=2400
# COMBINING@boundary=3840
# ***** PROCESSING 43_451870551.png ... *****
# ***** PROCESSING 43_453871552.png ... *****
# COMBINING@boundary=1422
# COMBINING@boundary=4740
# ***** PROCESSING 43_453872552.png ... *****
# COMBINING@boundary=1452
# COMBINING@boundary=1936
# COMBINING@boundary=4840
# ***** PROCESSING 44_453871552.png ... *****
# COMBINING@boundary=1868
# ***** PROCESSING 44_453872552.png ... *****
# COMBINING@boundary=4347
# ***** PROCESSING 44_453872553.png ... *****
# COMBINING@boundary=1932
# ***** PROCESSING 44_453873553.png ... *****
# COMBINING@boundary=1912
# ***** PROCESSING 44_454871552.png ... *****
# COMBINING@boundary=1876
# COMBINING@boundary=4221
# ***** PROCESSING 44_454872552.png ... *****
# COMBINING@boundary=4356
# ***** PROCESSING 44_454873553.png ... *****
# COMBINING@boundary=1916
# ***** PROCESSING 44_454873554.png ... *****
# ***** PROCESSING 44_455873553.png ... *****
# COMBINING@boundary=1900
# ***** PROCESSING 44_455873554.png ... *****
# COMBINING@boundary=1449
# COMBINING@boundary=4830
